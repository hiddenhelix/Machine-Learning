# %%
import warnings
from typing import Optional

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.axes import Axes
from sklearn.datasets import make_blobs, make_circles, make_moons
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    PrecisionRecallDisplay,
    RocCurveDisplay,
    accuracy_score,
    classification_report,
    roc_auc_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

warnings.filterwarnings("ignore")

# %%
# %matplotlib inline

# %% [markdown]
# Set random seed so that randomly generated data is the same every time.
# - However library versions may affect it. This notebook is made from python 3.14.0, numpy 2.3.4, sklearn 1.7.2.
# - You need to rerun everything to reproduce the same result. Rerunning a single cell may lead to different results even with the same parameters.
#
# **You're still welcomed to tweak and explore different parameters and also try different seeds. This note is only to tell you how to reproduce the default results.**

# %%
np.random.seed(42)  # determinism

# %% [markdown]
# # Overview
#
# In this notebook, we are going to explore  two binary linear classification models, concretely  Logistic Regression (LR) and Linear Discriminant Analysis (LDA). The main goals of this notebook are:
#
# - Learn how to use the plug-and-play models implemented in the Python package sklearn.
# - Evaluate robustness of both models to data perturbations
# - Explore the power of basis functions for linearly non-separable classes
# - Evaluate our models. Understand which metrics are (not) suitable for imbalance datasets.
#
# # Datasets
#
# We consider two datasets:
# - 2-dimensional isotropic Gaussian blobs. The samples for each class are generated from a gaussian distribution with a certain mean $\mathbf{\mu}$ and covariance $\sigma^{2}\mathbf{I}$ (off diagonal terms are $0$).
#
# - 2-dimensional circles.  Samples for each class are generated from circles with a certain radius plus some noise.

# %%
def plot_dataset(X: np.ndarray, y: np.ndarray, title: str, axes: Optional[Axes] = None):
    if axes is None:
        axes = plt.gca()
    y_zero = y == 0
    y_one = y == 1

    axes.scatter(X[y_zero, 0], X[y_zero, 1], color="red", label="Positive class")
    axes.scatter(X[y_one, 0], X[y_one, 1], color="blue", label="Negative class")
    axes.set_title(title)
    axes.set_xlabel("x1")
    axes.set_ylabel("x2")
    axes.legend()

# %%
n_samples = 100
X_blobs, y_blobs = make_blobs(n_samples=n_samples, centers=np.array([(-1, -1), (1, 1)]), cluster_std=0.5)
X_circles, y_circles = make_circles(n_samples=n_samples, factor=0.25, noise=0.05)

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))
plot_dataset(X_blobs, y_blobs, title="Blobs", axes=ax[0])
plot_dataset(X_circles, y_circles, title="Circles", axes=ax[1])

# %% [markdown]
# # Binary linear Classification
#  Let us assume  we have access to $n$ i.i.d. training samples $D_n = (\mathbf{x}_i, y_i)_{i=1}^n$, with $\mathbf{x}_i \in \mathbb{R}^d$. Throughout this notebook, we are going to focus on the **binary linear classification setting:**
#
#  - The **binary** part implies that our output (a.k.a. target or label) takes values $ y_i = \{-1,+1\}$.
#  - The **linear** part implies we consider a family of functions $f \in \mathcal{F}$ that are linear, i.e. $\mathcal{F} = \left\{\langle\mathbf{w}, \mathbf{x}\rangle+b, \text { with } \mathbf{x}, \mathbf{w} \in \mathbb{R}^{d}, b \in \mathbb{R}\right\}$. In particular, we consider the output (prediction) of our classifier is
#
#  $$
#  \hat{y}(\mathbf{x})=\operatorname{sign}(f(\mathbf{x}))=\operatorname{sign}(\langle\mathbf{w}, \mathbf{x}\rangle+b)=\left\{\begin{array}{ll}1 & \text { if }\langle\mathbf{w}, \mathbf{x}\rangle+b>0 \\ -1 & \text { if }\langle\mathbf{w}, \mathbf{x}\rangle+b \leq 0\end{array}\right.
#  $$
#
#
#
#
#  We refer to **decision boundary**  of the classifier $ \hat{y}(\mathbf{x}) = \operatorname{sign}(f(\mathbf{x}))$ to the set of points in the input spaces such that the output of $f(\mathbf{x})$ is zero, i.e. $\{\mathbf{x} \in \mathcal{X} \mid f(\mathbf{x})=0\}.$ Basically, the decision boundary separates the input space $\mathbb{R}^d$ into two half spaces.
#
#
#
# **Remark.** As with linear regression, we could also apply basis functions to map the input features $\mathbf{x}_i \in \mathbb{R}^d$ into a possibly larger feature space $\mathbb{R}^M$, i.e. $\mathbf{x} \in \mathbb{R}^{d} \longrightarrow\left(\phi_{1}(\mathbf{x}), \ldots, \phi_{M}(\mathbf{x})\right).$
#
# ## Logistic Regression (LR)
# Logitic regression is a supervised algorithm that models the conditional likelihood  $p(y | \mathbf{x})$ using a sigmoid function
#
# \begin{align}
# p=\mathrm{P}(Y=1 \mid X=\mathbf{x}, \mathbf{w}, b)=\frac{1}{1+e^{-\langle\mathbf{w}, \phi(\mathbf{x})\rangle + b }}
# \end{align}
#
# and finds the model parameters using Maximum Likelihood Estimation (MLE):
#
# \begin{align}
# \mathbf{w}^* & = \underset{\mathbf{w}}{\arg \max } \prod_{i=1}^{n} \mathrm{P}\left(Y=y_{i} \mid X=\mathbf{x}_{i}, \mathbf{w}\right)\\
# & = \underset{\mathbf{w}}{\arg \max } \sum_{i=1}^{n} \log \mathrm{P}\left(Y=y_{i} \mid X=\mathbf{x}_{i}, \mathbf{w}\right)\\
# & = \underset{\mathbf{w}}{\arg \min } \sum_{i=1}^{n} \log \left( 1+e^{-\langle\mathbf{w}, \phi(\mathbf{x})\rangle} \right)
# \end{align}
#
# ## Linear Discriminant Analysis (LDA)
# Linear Discriminant Analysis is a supervised algorithm that assumes our data $\mathbf{x}$ comes from a Gaussian distribution. LDA models the distribution $p(\mathbf{x} | y)$. Then, it tries to find the linear projection $\mathbf{w}$ that i) maximizes the distance between the means of the two classes, and ii) minimizes the variance within each class. It does so by maximizing the Fisher criterion:
#
# $$
# \mathbf{w}^{*}=\underset{\mathbf{w}}{\arg \max } J(\mathbf{w}) = \underset{\mathbf{w}}{\arg \max } \frac{\left\langle\mathbf{w}, m_{+}-m_{-}\right\rangle^{2}}{\sigma_{\mathbf{w},+}^{2}+\sigma_{\mathbf{w},-}^{2}}.
# $$
#
# To maximize the Fisher criterion we need to:
#
# 1. Compute the $d$-dimensional class centroids (a.k.a. means):
# $$
# m_{+}=\frac{1}{n_{+}} \sum_{\left\{i \mid Y_{i}=1\right\}} X_{i}, \quad m_{-}=\frac{1}{n_{-}} \sum_{\left\{i \mid Y_{i}=-1\right\}} X_{i}
# $$
#
# 2. Compute the within-class covariances of th projections of the positive and negative class:
#
# $$
# \sigma_{\mathbf{w},+}^{2}=\sum_{\left\{i \mid Y_{i}=1\right\}}\left(\left\langle\mathbf{w}, X_{i}\right\rangle-\left\langle\mathbf{w}, m_{+}\right\rangle\right)^{2}, \sigma_{\mathbf{w},-}^{2}=\sum_{\left\{i \mid Y_{i}=-1\right\}}\left(\left\langle\mathbf{w}, X_{i}\right\rangle-\left\langle\mathbf{w}, m_{-}\right\rangle\right)^{2}
# $$
#
#
# # Performance Metrics
#
# In order to determine the quality of a classifier $\hat{y}: \mathcal{X} \rightarrow \{-1,1\}$ on a dataset $D_n = (\mathbf{x}_i, y_i)_{i=1}^n$, the following
# metrics are commonly used.
#
#
# \begin{align}
#  &TP = \sum_{i=1}^n \mathbb{1}_{\hat{y}(x_i)=1 \; \wedge \; y_i=1} && \quad FN = \sum_{i=1}^n \mathbb{1}_{\hat{y}(x_i)=-1 \; \wedge \; y_i=1}\\
#  &FP = \sum_{i=1}^n \mathbb{1}_{\hat{y}(x_i)=1 \; \wedge \; y_i=-1} && \quad TN = \sum_{i=1}^n \mathbb{1}_{\hat{y}(x_i)=-1 \; \wedge \; y_i=-1}
# \end{align}
#
# **Accuracy** measures the percentage of observations that are correctly classified.
#   $$ Accuracy = \frac{TP+TN}{TP+TN+FP+FN} = \frac{1}{n}\sum_{i=1}^n \mathbb{1}_{f(x_i)=y_i}$$
#
# **Precision** measures how many predictions out of all positive predictions (i.e. TP+FP) are positive observations.
#                 $$ Precision = \frac{TP}{TP+FP} $$
#
# **Recall** measures how many observations out of all positive observations (i.e.TP+FN) have we classified as positive.
#                 $$ Recall = \frac{TP}{TP+FN} $$
# **False Positive Rate (FPR)** measures how many observations out of all negative observations (i.e.,N=FP+TN) have we classified as positive.
# $$FPR = \frac{FP}{FP+TN} $$
#
# **F1-score** is the harmonic mean of Precision + Recall.  It combines the two measures into one.Why do not just use the simple mean? Well, simply because the harmonic mean punishes extreme values.
#                 $$ F1\text{-}Score = 2 \cdot \frac{Precision \cdot Recall }{Precision + Recall } $$
#
#
# **ROC curve** plots the Recall versus the false positive rate (FPR) by varying the discrimination threshold $\theta \in [0,1]$.
#
# **PR curve** lots precision (PPV) versus the recall (TPR) by varying the discrimination threshold $\theta \in [0,1]$.
#
#
# For more information check: https://scikit-learn.org/stable/modules/lda_qda.html#lda-qda-math

# %% [markdown]
# # Robustness to data perturbations
#
# Analyze how do the decision boundaries of the two algorithms under study change when we add a second Gaussian blob.

# %% [markdown]
# ## Decision Boundary LDA
# The decision boundry for LDA is given by:
# $$ \{x \in \mathbb{R}^d |  \langle\mathbf{w}, \mathbf{x}\rangle+b = 0\}$$
#
# In order to determine a point on the decision boundry we can fix the first $d-1$ coordinates for $x \in \mathbb{R}^d$ and then solve for $x_d$.
# \begin{align}
#  \langle\mathbf{w}, \mathbf{x}\rangle+b &= 0
#  \quad\Leftrightarrow \quad \sum_{i=1}^d w_ix_i +b&= 0
#  \quad\Leftrightarrow \qquad  \,\,\, x_d &= -\frac{\sum_{i=1}^{d-1} w_ix_i + b}{w_d}
# \end{align}
#
#
# ## Decision Boundary Logistic Regression
#
# The descicion boundry for the logistic regression are all points, which satisfiy the following equation:
# \begin{align}
# p=\mathrm{P}(Y=1 \mid X=\mathbf{x}, \mathbf{w})=\frac{1}{1+e^{-(\langle\mathbf{w}, \mathbf{x}\rangle+b)}} = \frac{1}{2}
# \end{align}
# This is equivalent to:
# $$ e^{-(\langle\mathbf{w}, \mathbf{x}\rangle+b)} = 1$$
# Applying the $ln$ on both sides and multiplying by $-1$ yields:
# $$\langle\mathbf{w}, \mathbf{x}\rangle+b = 0 $$
# Now, we can proceed exactly as for the LDA.

# %%
def compute_lda_descicion_boundry(coef: np.ndarray, intercept: np.ndarray, x1: float, x2: float):
    w1, w2 = coef
    y1 = (-intercept - w1 * x1) / w2
    y2 = (-intercept - w1 * x2) / w2
    return [[x1, x2], [y1, y2]]


def compute_lr_descicion_boundry(coef: np.ndarray, intercept: np.ndarray, x1: float, x2: float):
    w1, w2 = coef
    y1 = -(w1 / w2) * x1 - intercept / w2
    y2 = -(w1 / w2) * x2 - intercept / w2
    return [[x1, x2], [y1, y2]]


def compute_svm_decision_boundary(coef: np.ndarray, intercept: np.ndarray, x1: float, x2: float):
    w1, w2 = coef
    y1 = 1 / (x1 * w1) - intercept
    y2 = 1 / (x2 * w2) - intercept
    return [[x1, x2], [y1, y2]]

# %%
lda = LinearDiscriminantAnalysis().fit(X_blobs, y_blobs)
lda_pred = lda.predict(X_blobs)
print(f"Accuracy LDA = {accuracy_score(y_blobs, lda_pred):.2f}")

logistic_regression = LogisticRegression().fit(X_blobs, y_blobs)
logistic_regression_pred = logistic_regression.predict(X_blobs)
print(f"Accuracy LR = {accuracy_score(y_blobs, logistic_regression_pred):.2f}")

fig, axes = plt.subplots(1, 1, figsize=(6, 4))
axes.plot(
    *compute_lda_descicion_boundry(lda.coef_[0], lda.intercept_, -3, 3), color="black", linestyle="dashed", label="LDA"
)
axes.plot(
    *compute_lr_descicion_boundry(logistic_regression.coef_[0], logistic_regression.intercept_, -3, 3),
    color="black",
    label="Log. Reg.",
)
plot_dataset(X_blobs, lda_pred, title="LDA vs Logistic Regression Prediction", axes=axes)
# Out:
# Accuracy LDA = 1.00
# Accuracy LR = 1.00

# %%
print(f"class centroids= {X_blobs[y_blobs==0].mean(0)} {X_blobs[y_blobs==1].mean(0)}")
# Out:
# class centroids= [-1.06783782 -1.0360087 ] [0.95227356 1.07003103]

# %%
print("Logistic Regression")
print(f"[w0, w1]= {logistic_regression.coef_[0]}")
print(f"b= {logistic_regression.intercept_[0]}")
print("\nLinear Discriminant Analysis")
print(f"[w0, w1]= {lda.coef_[0]}")
print(f"b= {lda.intercept_[0]}")
print(f"class centroids= {lda.means_[0]} {lda.means_[1]}")
# Out:
# Logistic Regression
# [w0, w1]= [2.06707352 2.03901823]
# b= 0.05712992462759679
#
# Linear Discriminant Analysis
# [w0, w1]= [10.62995472  8.17965405]
# b= 0.4750759759055967
# class centroids= [-1.06783782 -1.0360087 ] [0.95227356 1.07003103]

# %% [markdown]
# Now, we will add a second blob to the positive class.
# ### Observe
# How do the decision boundaries change? Which algorithm is more robust to outliers?

# %%
mean = [5, 2]
cov = [[0.2, 0], [0, 0.2]]
num = 40
outlier = np.random.multivariate_normal(mean, cov, num)

X_plobs_outlier = np.concatenate((X_blobs, outlier))
y_blobs_outlier = np.concatenate((y_blobs, np.ones(outlier.shape[0])))
plot_dataset(X_plobs_outlier, y_blobs_outlier, title="Blobs")

# %%
lda = LinearDiscriminantAnalysis().fit(X_plobs_outlier, y_blobs_outlier)  # Train Linear Discriminant Analysis (LDA)
lda_pred = lda.predict(X_plobs_outlier)

print(f"Accuracy LDA = {accuracy_score(y_blobs_outlier, lda_pred):.2f}")

logistic_regression = LogisticRegression().fit(X_plobs_outlier, y_blobs_outlier)  # Train Logistic Regression (LR)
logistic_regression_pred = logistic_regression.predict(X_plobs_outlier)
print(f"Accuracy LR = {accuracy_score(y_blobs_outlier, logistic_regression_pred):.2f}")
# Out:
# Accuracy LDA = 1.00
# Accuracy LR = 1.00

# %%
fig, axes = plt.subplots(1, 1, figsize=(6, 4))
axes.plot(
    *compute_lda_descicion_boundry(lda.coef_[0], lda.intercept_, -3, 5), color="black", linestyle="dashed", label="LDA"
)
axes.plot(
    *compute_lr_descicion_boundry(logistic_regression.coef_[0], logistic_regression.intercept_, -3, 3),
    color="black",
    label="Log. Reg."
)
plot_dataset(X_plobs_outlier, lda_pred, title="LDA vs Logistic Regression Prediction", axes=axes)

# %%
print("Logistic Regression")
print(f"[w0, w1]= {logistic_regression.coef_[0]}")
print(f"b= {logistic_regression.intercept_[0]}")
print("\nLinear Discriminant Analysis")
print(f"[w0, w1]= {lda.coef_[0]}")
print(f"b= {lda.intercept_[0]}")
print(f"class centroids= {lda.means_[0]} {lda.means_[1]}")
# Out:
# Logistic Regression
# [w0, w1]= [2.07508504 2.03437479]
# b= 0.059525675793364326
#
# Linear Discriminant Analysis
# [w0, w1]= [-0.08063787  6.43936327]
# b= -0.8408913168369936
# class centroids= [-1.06783782 -1.0360087 ] [2.81040657 1.50156296]

# %% [markdown]
# ### Question
# Looking at the decision boundary obtained...What is happening in the LDA optimization?

# %% [markdown]
# From now on, we will focus on the Logistic Regression classifier.

# %% [markdown]
# # Introducing basis functions

# %% [markdown]
# First, we fit a Logistic Regression model on vanilla linear features.

# %%
logistic_regression = LogisticRegression().fit(X_circles, y_circles)
logistic_regression_pred = logistic_regression.predict(X_circles)

print(f"Accuracy={accuracy_score(y_circles, logistic_regression_pred):.2f}")
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
plot_dataset(X_circles, y_circles, title="True", axes=ax[0])
ax[1].plot(
    *compute_lr_descicion_boundry(logistic_regression.coef_[0], logistic_regression.intercept_, -1.1, 1.1),
    color="black",
    linestyle="--",
    label="Dec. Boundary",
)
ax[1].set_ylim(-1.2, 1.2)
plot_dataset(X_circles, logistic_regression_pred, title="Prediction", axes=ax[1])
# Out:
# Accuracy=0.51

# %% [markdown]
# Clearly, the data is not linearly seperable. Now, there are two possibilities to tackle this problem. One could use a non-linear classifier, that has sufficient capacity to model such a descicion boundry. Or, one could transform the data, such that it becomes linearly seperable. This is also the approach presented in the following: <br>
#
# We use the transformation:
# $$ \phi:\mathbb{R}^2 \rightarrow \mathbb{R}^3, \; (x_1,x_2)^T \mapsto (x_1,x_2,x_1^2 + x_2^2)^T $$

# %%
t = lambda x, y: (np.square(x) + np.square(y)).reshape(-1, 1)
X_t = t(X_circles[:, 0], X_circles[:, 1])
X_transformed = np.concatenate((X_circles, X_t), axis=1)
red = y_circles == 0
blue = y_circles == 1

fig = plt.figure(figsize=(18, 8))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122, projection="3d")

plot_dataset(X_circles, y_circles, title="Vanilla", axes=ax1)

ax2.scatter3D(X_transformed[red, 0], X_transformed[red, 1], X_transformed[red, 2], color="red", label="Class 0")
ax2.scatter(X_transformed[blue, 0], X_transformed[blue, 1], X_transformed[blue, 2], color="blue", label="Class 1")
ax2.set_xlabel("x1")
ax2.set_ylabel("x2")
ax2.set_zlabel("z")
ax2.set_title("Transformed")
ax2.legend()
plt.show()

# %% [markdown]
# As a next, we fit a LR model on the transformed data and plot the descicion surface.

# %%
logistic_regression_t = LogisticRegression().fit(X_transformed, y_circles)
logistic_regression_pred_t = logistic_regression_t.predict(X_transformed)
x = np.linspace(-2, 2, 100)
x1, x2 = np.meshgrid(x, x)

w1, w2, w3 = logistic_regression_t.coef_[0]
b = logistic_regression_t.intercept_

z = -w2 / w3 * x2 - w1 / w3 * x1 - b / w3

fig = plt.figure(figsize=(10, 9))
ax = fig.add_subplot(projection="3d")
red = y_circles == 0
blue = y_circles == 1

ax.scatter(X_transformed[red, 0], X_transformed[red, 1], X_transformed[red, 2], color="red", label="Class 0")
ax.scatter(X_transformed[blue, 0], X_transformed[blue, 1], X_transformed[blue, 2], color="blue", label="Class 1")
surf = ax.plot_surface(x1, x2, z, alpha=0.1, color="black", label="Desicion surface")
# https://stackoverflow.com/questions/54994600/pyplot-legend-poly3dcollection-object-has-no-attribute-edgecolors2d
surf._facecolors2d = surf._facecolor3d
surf._edgecolors2d = surf._edgecolor3d
ax.set_xlabel("x1")
ax.set_ylabel("x2")
ax.set_zlabel("z")
print(f"Accuracy on vanilla data: {accuracy_score(y_circles, logistic_regression_pred):.2f}")
print(f"Accuracy on transformed data: {accuracy_score(y_circles, logistic_regression_pred_t):.2f}")
ax.legend()
plt.show()
# Out:
# Accuracy on vanilla data: 0.51
# Accuracy on transformed data: 1.00

# %% [markdown]
# # Exploring evaluation metrics
#
# In the following, we are gonna explore different evaluation metrics

# %%
mean = [-1, 0]
cov = [[0.3, 0], [0, 0.3]]
num = 20
outlier = np.random.multivariate_normal(mean, cov, num)

X_blobs_2 = np.concatenate((X_blobs, outlier))
y_blobs_2 = np.concatenate((y_blobs, np.ones(outlier.shape[0])))
plot_dataset(X_blobs_2, y_blobs_2, title="Blobs")

# %%
logistic_regression = LogisticRegression().fit(X_blobs_2, y_blobs_2)
logistic_regression_pred = logistic_regression.predict(X_blobs_2)

print(f"Accuracy={accuracy_score(y_blobs_2, logistic_regression_pred):.2f}")
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.plot(
    *compute_lr_descicion_boundry(logistic_regression.coef_[0], logistic_regression.intercept_, -5, 2.0),
    color="black",
    linestyle="--",
    label="Dec. Boundary",
)
plot_dataset(X_blobs_2, y_blobs_2, title="True Labels", axes=ax)
# Out:
# Accuracy=0.89

# %% [markdown]
#  Compare precision/recall/accuracy/F1 score.

# %%
print(classification_report(y_blobs_2, logistic_regression_pred, target_names=["Class 0", "Class 1"]))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.85      0.90      0.87        50
#      Class 1       0.93      0.89      0.91        70
#
#     accuracy                           0.89       120
#    macro avg       0.89      0.89      0.89       120
# weighted avg       0.89      0.89      0.89       120

# %% [markdown]
#  Plot confusion matrix

# %%
ConfusionMatrixDisplay.from_estimator(logistic_regression, X_blobs_2, y_blobs_2, labels=[0, 1], normalize="true")
plt.show()

# %% [markdown]
# ROC curve

# %%
RocCurveDisplay.from_estimator(logistic_regression, X_blobs_2, y_blobs_2)
plt.show()

# %%
PrecisionRecallDisplay.from_estimator(logistic_regression, X_blobs_2, y_blobs_2)
plt.show()

# %% [markdown]
# # Binary classification: Unbalanced classes
# - Plot the decision boundaries of Logistic Regression when training with a dataset w/o basis functions with non Linear separable dataset.
# - Compare precision/recall/accuracy/F1 score (use https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# - Plot confusion matrix
# - ROC curve
# - PR curve curve

# %%
# make imbalenced blobs
def make_imbalanced_blobs(n_samples: list[int]):
    X1, y1 = make_blobs(n_samples=2 * n_samples[0], centers=np.array([(-1, -1), (1, 1)]), cluster_std=1.5)
    X2, y2 = make_blobs(n_samples=2 * n_samples[1], centers=np.array([(-1, -1), (1, 1)]), cluster_std=1.5)
    return np.concatenate((X1[y1 == 0], X2[y2 == 1])), np.concatenate((y1[y1 == 0], y2[y2 == 1]))

# %%
X_blobs_imbalanced, y_blobs_imbalanced = make_imbalanced_blobs([1000, 50])
# logistic_regression = LogisticRegression(class_weight=None).fit(X_moons_imbalanced,y_moons_imbalanced)
logistic_regression = LogisticRegression(class_weight={0: 1, 1: 20}).fit(X_blobs_imbalanced, y_blobs_imbalanced)

logistic_regression_pred = logistic_regression.predict(X_blobs_imbalanced)
print(f"Accuracy={accuracy_score(y_blobs_imbalanced, logistic_regression_pred):.2f}")

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(
    *compute_lr_descicion_boundry(logistic_regression.coef_[0], logistic_regression.intercept_, -4.2, 4.2),
    color="black",
    linestyle="--",
    label="Dec. Boundary",
)

plot_dataset(X_blobs_imbalanced, y_blobs_imbalanced, title="True", axes=ax[0])
ax[1].plot(
    *compute_lr_descicion_boundry(logistic_regression.coef_[0], logistic_regression.intercept_, -4.2, 4.2),
    color="black",
    linestyle="--",
    label="Dec. Boundary",
)
plot_dataset(X_blobs_imbalanced, logistic_regression_pred, title="Prediction", axes=ax[1])
# Out:
# Accuracy=0.77

# %%
print(classification_report(y_blobs_imbalanced, logistic_regression_pred, target_names=["Class 0", "Class 1"]))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.77      0.86      1000
#      Class 1       0.14      0.78      0.24        50
#
#     accuracy                           0.77      1050
#    macro avg       0.56      0.77      0.55      1050
# weighted avg       0.95      0.77      0.83      1050

# %%
RocCurveDisplay.from_estimator(logistic_regression, X_blobs_imbalanced, y_blobs_imbalanced)
plt.show()

# %%
PrecisionRecallDisplay.from_estimator(logistic_regression, X_blobs_imbalanced, y_blobs_imbalanced)
plt.show()

# %% [markdown]
# ## Plots Examples

# %%
n_samples = 300
X_blobs, y_blobs = make_blobs(n_samples=n_samples, centers=np.array([(-1, -1), (1.5, 1)]), cluster_std=(0.3, 0.6))
plot_dataset(X_blobs, y_blobs, title="Blobs")

# %%
# Logistic Regression
logistic_regression1 = LogisticRegression(penalty=None, class_weight="balanced").fit(X_blobs, y_blobs)
logistic_regression_pred1 = logistic_regression.predict(X_blobs)


# LDA classfier
lda = LinearDiscriminantAnalysis().fit(X_blobs, y_blobs)
lda_pred = lda.predict(X_blobs)

# Another Logistic Regression
logistic_regression = LogisticRegression().fit(X_blobs, y_blobs)
logistic_regression_pred = logistic_regression.predict(X_blobs)

fig, axes = plt.subplots(1, 1, figsize=(6, 4))
axes.plot(
    *compute_lr_descicion_boundry(logistic_regression.coef_[0], logistic_regression.intercept_, -4, 4),
    color="black",
    linestyle="solid",
    label="Linear Separable"
)
axes.plot(
    *compute_lr_descicion_boundry(logistic_regression1.coef_[0], logistic_regression1.intercept_, -4, 4),
    color="black",
    linestyle="dashed",
    label="Linear Separable II"
)
axes.plot(
    *compute_lda_descicion_boundry(lda.coef_[0], lda.intercept_, -4, 4),
    color="black",
    linestyle="dotted",
    label="Linear Separable I"
)
plot_dataset(X_blobs, lda_pred, title="Linear Separable Data", axes=axes)

# %% [markdown]
# ### Adding a second Gaussian blob

# %%
mean = [5, 2]
cov = [[0.2, 0], [0, 0.2]]
num = 100
outlier = np.random.multivariate_normal(mean, cov, num)

X_blobs_outlier = np.concatenate((X_blobs, outlier))
y_blobs_outlier = np.concatenate((y_blobs, np.ones(outlier.shape[0])))
plot_dataset(X_blobs_outlier, y_blobs_outlier, title="Blobs")

# %%
# LDA classfier
lda_outlier = LinearDiscriminantAnalysis().fit(X_blobs_outlier, y_blobs_outlier)
lda_pred_outlier = lda.predict(X_blobs_outlier)

# Logistic Regression
logistic_regression_outlier = LogisticRegression().fit(X_blobs_outlier, y_blobs_outlier)
logistic_regression_pred_outlier = logistic_regression.predict(X_blobs_outlier)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(
    *compute_lr_descicion_boundry(logistic_regression.coef_[0], logistic_regression.intercept_, -4, 4),
    color="black",
    linestyle="solid",
    label="Logistic Regression Boundary"
)
axes[0].plot(
    *compute_lda_descicion_boundry(lda.coef_[0], lda.intercept_, -4, 4),
    color="black",
    linestyle="dotted",
    label="LDA Boundary"
)
plot_dataset(X_blobs, lda_pred, title="Comparison of LDA and Logistic Regression", axes=axes[0])
axes[0].get_legend().remove()
axes[1].plot(
    *compute_lr_descicion_boundry(logistic_regression_outlier.coef_[0], logistic_regression_outlier.intercept_, -4, 6),
    color="black",
    linestyle="solid",
    label="Logistic Regression Boundary"
)
axes[1].plot(
    *compute_lda_descicion_boundry(lda_outlier.coef_[0], lda_outlier.intercept_, -4, 6),
    color="black",
    linestyle="dotted",
    label="LDA Boundary"
)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)
plot_dataset(X_blobs_outlier, lda_pred_outlier, title="Comparison of LDA and Logistic Regression", axes=axes[1])

# %%
def plot_dataset_mean(X: np.ndarray, y: np.ndarray, title: str, axes: Optional[Axes] = None):
    if axes is None:
        axes = plt.gca()
    y_zero = y == 0
    y_one = y == 1

    axes.scatter(X[y_zero, 0], X[y_zero, 1], color="red", label="Positive class")
    axes.scatter(
        X[y_zero, 0].mean(),
        X[y_zero, 1].mean(),
        color="black",
        marker="^",
        label="Positive class mean",
        edgecolors="red",
        s=150,
    )
    axes.scatter(X[y_one, 0], X[y_one, 1], color="blue", label="Negative class")
    axes.scatter(
        X[y_one, 0].mean(),
        X[y_one, 1].mean(),
        color="black",
        marker="^",
        label="Negative class mean",
        edgecolors="blue",
        s=150,
    )
    axes.set_title(title)
    axes.set_xlabel("x1")
    axes.set_ylabel("x2")
    axes.legend(prop={"size": 10}, loc="upper left")

# %% [markdown]
# ### Gaussian blobs with different std

# %%
n_samples = 300
X_blobs, y_blobs = make_blobs(n_samples=n_samples, centers=np.array([(-0.5, -0.5), (0.5, 0.5)]), cluster_std=(0.2, 0.3))
plot_dataset_mean(X_blobs, y_blobs, title="Blobs")

# %%
def class_means(X: np.ndarray, y: np.ndarray):
    y_zero = y == 0
    y_one = y == 1
    # Calculate the means of each class
    class_0_mean = np.mean(X[y_zero].T, axis=1)
    class_1_mean = np.mean(X[y_one].T, axis=1)

    return class_0_mean, class_1_mean


def class_covs(X: np.ndarray, y: np.ndarray):
    y_zero = y == 0
    y_one = y == 1
    # Calculate the covs of each class
    class_0_cov = np.cov(X[y_zero].T)
    class_1_cov = np.cov(X[y_one].T)

    return class_0_cov, class_1_cov


def fischer_criterion(X: np.ndarray, y: np.ndarray, w: np.ndarray):
    """
    Calculates the Fischer criterion for a given set of x and y values.
    """

    class_0_mean, class_1_mean = class_means(X, y)
    class_0_cov, class_1_cov = class_covs(X, y)

    between_class_cov = np.outer((class_1_mean - class_0_mean), (class_1_mean - class_0_mean))
    within_class_cov = class_0_cov + class_1_cov

    num = w.T @ (between_class_cov @ w)
    denum = w.T @ (within_class_cov @ w)

    # print(f"weight shape {w.shape}, within class cov {within_class_cov.shape}, between class cov {between_class_cov.shape}")
    # print(f"weight {w}, within class cov {within_class_cov}, between class cov {between_class_cov}")
    return (num / denum).diagonal()

# %%
lda = LinearDiscriminantAnalysis().fit(X_blobs, y_blobs)
lda_pred = lda.predict(X_blobs)

class_0_mean, class_1_mean = class_means(X_blobs, y_blobs)
intercept = 0.5 * (class_0_mean + class_1_mean)

# Fischer criterion of different weights
w_angle = np.linspace(0, np.pi, 2000)
cos_w = np.cos(w_angle)
sin_w = np.sin(w_angle)
w = np.stack([cos_w, sin_w], axis=0)
fischer_scores = fischer_criterion(X_blobs, y_blobs, w)
w_star = w[:, np.argmax(fischer_scores)]

fig, axes = plt.subplots(1, 1, figsize=(7, 7))
axes.plot(w_angle, fischer_scores, color="red")
axes.set_xlabel(r"Angle $\omega$")
axes.set_ylabel("Fischer criterion")
axes.set_ylim(bottom=0)
axes.set_title(r"Fischer Criterion of weights with different angle $\omega$ ")
plt.show()


fig, axes = plt.subplots(1, 1, figsize=(7, 7))
axes.set_xlim(-2, 2)
axes.set_ylim(-2, 2)
axes.plot(
    *compute_lda_descicion_boundry(lda.coef_[0], lda.intercept_, -2, 2),
    color="black",
    linestyle="-",
    label="LDA decision boundary"
)
slope = w_star[1] / w_star[0]
xs = np.linspace(2, -2, 100) * w_star[0]
ys = np.linspace(2, -2, 100) * w_star[1]
axes.plot(xs, ys, color="black", linestyle="--", label=r"Projection line $\alpha w^{*}$")
plot_dataset_mean(X_blobs, y_blobs, title="LDA Prediction", axes=axes)

# %% [markdown]
# ### Linearly separable data

# %%
# Generate a linearly separable dataset
# X, y = make_classification(n_samples=10000, n_classes=2)
X, y = make_blobs(n_samples=2000, centers=np.array([(-1, -1), (1, 1)]), cluster_std=0.1)
plot_dataset(X, y, title="Blobs")

# split into train/test sets
trainX, testX, trainy, testy = train_test_split(X, y, test_size=0.75, random_state=2)

# Define the classifiers
classifiers = [
    ("Logistic Regression", LogisticRegression()),
    ("Linear SVM", SVC(kernel="linear", probability=True)),
    ("Polynomial SVM", SVC(kernel="poly", degree=3, gamma="auto", probability=True)),
    ("RBF SVM", SVC(kernel="rbf", degree=3, gamma="scale", probability=True)),
    ("Constant Classifier", np.zeros(len(testy))),
    ("Random Classifier", np.random.uniform(low=0.0, high=1.0, size=len(testy))),
]

# %%
fig, ax = plt.subplots(figsize=(8, 8))

for name, lr in classifiers:
    if isinstance(lr, SVC) or isinstance(lr, RandomForestClassifier) or isinstance(lr, LogisticRegression):
        lr.fit(trainX, trainy)
        pred = lr.predict(testX)
        lr_probs = lr.predict_proba(testX)
        # keep probabilities for the positive outcome only
        lr_probs = lr_probs[:, 1]
        fpr, tpr, thresholds = roc_curve(testy, lr_probs)
    else:
        lr = lr.reshape(-1)
        lr_probs = lr  # 1 / (1 + np.exp(-lr))
        pred = lr_probs > 0.5
        fpr, tpr, _ = roc_curve(testy, lr_probs)
    err = 1 - accuracy_score(y_true=testy, y_pred=pred)
    auc_score = roc_auc_score(testy, lr_probs)
    plt.plot(fpr, tpr, label=f"{name}, AUC={auc_score:.3f}, Err={err:.3f}")

# Set the title, axis labels and legend
ax.set_title("ROC curve for separable data")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.legend()

plt.show()

# %% [markdown]
# ### Moons

# %%
# Generate a non-separable dataset
X, y = make_moons(n_samples=1000, noise=0.1, random_state=2)
plot_dataset(X, y, title="Moons")
# split into train/test sets
trainX, testX, trainy, testy = train_test_split(X, y, test_size=0.75, random_state=2)

classifiers = [
    ("Logistic Regression", LogisticRegression()),
    ("Linear SVM", SVC(kernel="linear", probability=True)),
    ("Polynomial SVM", SVC(kernel="poly", degree=3, gamma="auto", probability=True)),
    ("RBF SVM ", SVC(kernel="rbf", degree=3, gamma="scale", probability=True)),
    ("RandomForest", RandomForestClassifier(max_depth=2, random_state=0)),
    ("Constant Classifier", np.zeros(len(testy))),
    ("Random Classifier", np.random.uniform(low=0.0, high=1.0, size=len(testy))),
]

# %%
fig, ax = plt.subplots(figsize=(8, 8))
for name, lr in classifiers:
    if isinstance(lr, SVC) or isinstance(lr, RandomForestClassifier) or isinstance(lr, LogisticRegression):
        lr.fit(trainX, trainy)
        pred = lr.predict(testX)
        lr_probs = lr.predict_proba(testX)
        # keep probabilities for the positive outcome only
        lr_probs = lr_probs[:, 1]
        fpr, tpr, thresholds = roc_curve(testy, lr_probs)
    else:
        lr = lr.reshape(-1)
        lr_probs = lr  # 1 / (1 + np.exp(-lr))
        pred = lr_probs > 0.5
        fpr, tpr, _ = roc_curve(testy, lr_probs)
    err = 1 - accuracy_score(y_true=testy, y_pred=pred)
    auc_score = roc_auc_score(testy, lr_probs)
    plt.plot(fpr, tpr, label=f"{name}, AUC={auc_score:.3f}, Err={err:.3f}")

# Set the title, axis labels and legend
ax.set_title("ROC curve for non-separable data")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.legend()

plt.show()
